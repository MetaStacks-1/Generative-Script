# %%
from PIL import Image, ImageOps
from IPython.display import display
import json


for i in range(6970):
  with open(f'/home/william/Brkfst World/Generator/metadata/{i}.json', "r") as jsonFile:
      data = json.load(jsonFile)
      for d in data["attributes"]:
        if d["value"] == "None":
            data["attributes"].pop()
      data["image"] = f'https://gateway.pinata.cloud/ipfs/QmTxSi3QSqCXiqQR5b2ZQVXsFSR8mqHZHx7V9KNvwrS1b2/{i}.png'
      with open(f'/home/william/Brkfst World/Generator/metadatafinal/{i}', "w") as jsonFile:
        json.dump(data, jsonFile)
        
for i in range(6970):
  with open(f'/home/william/Brkfst World/Generator/metadata/{i}.json', "r") as jsonFile:
      data = json.load(jsonFile)
      del data["attributes"]
      data["image"] = f'https://gateway.pinata.cloud/ipfs/QmWKfQjTMSVrGxeSiRw654SFAKfxA8a5zNGb3ovzN3S3tD'
      with open(f'/home/william/Brkfst World/Generator/metadatadummy/{i}', "w") as jsonFile:
        json.dump(data, jsonFile)
